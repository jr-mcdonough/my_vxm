# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# one package not installed already on colab
# !pip install pystrum
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pystrum: filename=pystrum-0.4-py3-none-any.whl size=19533 sha256=e3a7d92bca94c64c63fc23b0e801782d99429e4ac378061177acda2858c7a413
#   Stored in directory: /root/.cache/pip/wheels/aa/08/d0/914025beb5a12a855b8aafd22eeedc547198684a3f4409f66c
# Successfully built pystrum
# ...

# %%
# %run -i /content/drive/My\ Drive/EC500/test_registration.py --imgs_source 'dict'  --imgs_path '/content/drive/My Drive/EC500/2Dreg_traintest/dicts/test_dict.npz' --model_dir '/content/drive/My Drive/EC500/reg_models' --eval_dir '/content/drive/My Drive/EC500/reg_models/model_eval'
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
