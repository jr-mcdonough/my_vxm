# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# one package not installed already on colab
# !pip install pystrum
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pystrum: filename=pystrum-0.4-py3-none-any.whl size=19533 sha256=23278c8508edd6e8b83a04a6f07e46368010568f517c1cbd112133ca5b3b2dbb
#   Stored in directory: /root/.cache/pip/wheels/aa/08/d0/914025beb5a12a855b8aafd22eeedc547198684a3f4409f66c
# Successfully built pystrum
# ...

# %%
# %run -i /content/drive/My\ Drive/EC500/test_atlas.py --imgs_source 'dict'  --imgs_path '/content/drive/My Drive/EC500/2Dreg_traintest/dicts/test_dict.npz' --reg_model_dir '/content/drive/My Drive/EC500/atlas_models/registration' --atlas_model_dir '/content/drive/My Drive/EC500/atlas_models/atlas' --eval_dir '/content/drive/My Drive/EC500/atlas_models/model_eval'
# Out:
# /content/drive/My Drive/EC500/vxm_torch/modelio.py:74: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location=torch.device(device))
# ...

# %%
# %run -i /content/drive/My\ Drive/EC500/test_atlas.py --imgs_source 'dict'  --imgs_path '/content/drive/My Drive/EC500/2Dreg_traintest/dicts/test_dict.npz' --reg_model_dir '/content/drive/My Drive/EC500/atlas_models/pretrained_reg/registration' --atlas_model_dir '/content/drive/My Drive/EC500/atlas_models/pretrained_reg/atlas' --eval_dir '/content/drive/My Drive/EC500/atlas_models/pretrained_reg/model_eval'
# Out:
# /content/drive/My Drive/EC500/atlas_models/pretrained_reg/registration/0000.pt
#  - loss: 4.5488e-03  (2.2744e-03, 2.2744e-03, 1.5416e-15) - mean dice score: 5.2327e-01, mean dice score (no background) 5.0805e-01
# /content/drive/My Drive/EC500/atlas_models/pretrained_reg/registration/0020.pt
#  - loss: 4.5333e-03  (2.2666e-03, 2.2666e-03, 5.8352e-16) - mean dice score: 4.8784e-01, mean dice score (no background) 4.7117e-01
# /content/drive/My Drive/EC500/atlas_models/pretrained_reg/registration/0040.pt
#  - loss: 4.6086e-03  (2.3043e-03, 2.3043e-03, 7.3324e-16) - mean dice score: 4.9457e-01, mean dice score (no background) 4.7813e-01
# /content/drive/My Drive/EC500/atlas_models/pretrained_reg/registration/0060.pt
#  - loss: 4.8465e-03  (2.4233e-03, 2.4233e-03, 5.4040e-16) - mean dice score: 5.0069e-01, mean dice score (no background) 4.8453e-01
# /content/drive/My Drive/EC500/atlas_models/pretrained_reg/registration/0080.pt
# ...
