# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# one package not installed already on colab
# !pip install pystrum
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pystrum: filename=pystrum-0.4-py3-none-any.whl size=19533 sha256=6bbf56340bee3b2e9faa6dd694b9d0943229bd786dfe3e83c630c8bf09863028
#   Stored in directory: /root/.cache/pip/wheels/aa/08/d0/914025beb5a12a855b8aafd22eeedc547198684a3f4409f66c
# Successfully built pystrum
# ...

# %%
# %run -i /content/drive/My\ Drive/EC500/train_atlas.py --imgs_source 'dict'  --imgs_path '/content/drive/My Drive/EC500/2Dreg_traintest/dicts/training_dict.npz' --reg_model_dir '/content/drive/My Drive/EC500/atlas_models/registration' --atlas_model_dir '/content/drive/My Drive/EC500/atlas_models/atlas' --loss_dir '/content/drive/My Drive/EC500/atlas_models/training_loss'
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch 1/1500 - 0.0460 sec/step - loss: 4.0802e-03  (2.0674e-03, 2.0122e-03, 5.8092e-07)
# Epoch 2/1500 - 0.0283 sec/step - loss: 4.0924e-03  (2.1183e-03, 1.9721e-03, 2.0418e-06)
# Epoch 3/1500 - 0.0278 sec/step - loss: 3.8872e-03  (2.0176e-03, 1.8673e-03, 2.3932e-06)
# Epoch 4/1500 - 0.0222 sec/step - loss: 3.9377e-03  (2.0489e-03, 1.8837e-03, 4.9909e-06)
# Epoch 5/1500 - 0.0229 sec/step - loss: 4.0114e-03  (2.1149e-03, 1.8477e-03, 4.8729e-05)
# Epoch 6/1500 - 0.0229 sec/step - loss: 3.5408e-03  (1.8593e-03, 1.5436e-03, 1.3786e-04)
# Epoch 7/1500 - 0.0254 sec/step - loss: 3.2667e-03  (1.6711e-03, 1.3539e-03, 2.4171e-04)
# ...
