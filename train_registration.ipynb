# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# one package not installed already on colab
# !pip install pystrum
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pystrum: filename=pystrum-0.4-py3-none-any.whl size=19533 sha256=de2979ade7cfcecd3ea368624534e858d582f15a382e2622b1da546700c97f51
#   Stored in directory: /root/.cache/pip/wheels/aa/08/d0/914025beb5a12a855b8aafd22eeedc547198684a3f4409f66c
# Successfully built pystrum
# ...

# %%
# %run -i /content/drive/My\ Drive/EC500/train_registration.py --imgs_source 'dict'  --imgs_path '/content/drive/My Drive/EC500/2Dreg_traintest/dicts/training_dict.npz' --model_dir '/content/drive/My Drive/EC500/reg_models' --loss_dir '/content/drive/My Drive/EC500/reg_models/training_loss'
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch 1/1500 - 0.0452 sec/step - loss: 8.0586e-03  (4.0288e-03, 4.0292e-03, 5.8660e-07)
# Epoch 2/1500 - 0.0291 sec/step - loss: 8.5038e-03  (4.2462e-03, 4.2556e-03, 1.9692e-06)
# Epoch 3/1500 - 0.0235 sec/step - loss: 8.1621e-03  (4.0781e-03, 4.0819e-03, 2.1116e-06)
# Epoch 4/1500 - 0.0212 sec/step - loss: 8.0106e-03  (4.0048e-03, 4.0036e-03, 2.2080e-06)
# Epoch 5/1500 - 0.0211 sec/step - loss: 8.2070e-03  (4.1024e-03, 4.1016e-03, 3.0488e-06)
# Epoch 6/1500 - 0.0213 sec/step - loss: 8.0131e-03  (4.0117e-03, 3.9966e-03, 4.8960e-06)
# Epoch 7/1500 - 0.0233 sec/step - loss: 6.9882e-03  (3.3971e-03, 3.3971e-03, 1.9393e-04)
# ...
